# %%
import pandas as pd
import os

# %%
####Merging 12 months of data into a single file

# %%
df = pd.read_csv("C:/Users/ACS/OneDrive/Desktop/Jupyter Projects/Sales_Data/Sales_April_2019.csv")
folder_path = r"C:\Users\ACS\OneDrive\Desktop\Jupyter Projects\Sales_Data"
files = [file for file in os.listdir(folder_path)]

for file in files:
    print(file)
# Out:
# Sales_April_2019.csv
# Sales_August_2019.csv
# Sales_December_2019.csv
# Sales_February_2019.csv
# Sales_January_2019.csv
# Sales_July_2019.csv
# Sales_June_2019.csv
# Sales_March_2019.csv
# Sales_May_2019.csv
# Sales_November_2019.csv
# Sales_October_2019.csv
# Sales_September_2019.csv
